# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\USER\Downloads\Invoices for today\Messy_Excel_Data\Messy_Excel_Data\data\data_cleaned.xlsx")

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#             Order ID  Returned  Postal Code   Region       Product ID  \
# 0     CA-2017-114412     False        28027    South  OFF-PA-10002365
# 1     US-2017-156909     False        19140     East  FUR-CH-10002774
# 2     CA-2017-107727     False         7090  Central  OFF-PA-10000249
# 3     CA-2017-120999      True        60540  Central  TEC-PH-10004093
# 4     CA-2017-139619     False         1852    South  OFF-ST-10003282
# ...              ...       ...          ...      ...              ...
# 3307  CA-2017-163629     False        30605    South  TEC-PH-10004006
# 3308  CA-2017-121258      True        92627     West  FUR-FU-10000747
# 3309  CA-2017-121258      True        92627     West  TEC-PH-10003645
# 3310  CA-2017-121258      True        92627     West  OFF-PA-10004041
# 3311  CA-2017-119914     False        92683     West  OFF-AP-10002684
#
#              Category Sub-Category  \
# 0     Office Supplies        Paper
# 1           Furniture       Chairs
# ...

# %%
df["Returned"] = df["Returned"].apply(lambda x : str(x))

# %%
df #we would like to know the number of products that were returned.
# Out:
#             Order ID Returned  Postal Code   Region       Product ID  \
# 0     CA-2017-114412    False        28027    South  OFF-PA-10002365
# 1     US-2017-156909    False        19140     East  FUR-CH-10002774
# 2     CA-2017-107727    False         7090  Central  OFF-PA-10000249
# 3     CA-2017-120999     True        60540  Central  TEC-PH-10004093
# 4     CA-2017-139619    False         1852    South  OFF-ST-10003282
# ...              ...      ...          ...      ...              ...
# 3307  CA-2017-163629    False        30605    South  TEC-PH-10004006
# 3308  CA-2017-121258     True        92627     West  FUR-FU-10000747
# 3309  CA-2017-121258     True        92627     West  TEC-PH-10003645
# 3310  CA-2017-121258     True        92627     West  OFF-PA-10004041
# 3311  CA-2017-119914    False        92683     West  OFF-AP-10002684
#
#              Category Sub-Category  \
# 0     Office Supplies        Paper
# 1           Furniture       Chairs
# ...

# %%
for x in df.index:
    if df.loc[x, "Returned"] == "False":
        df.drop(x,inplace=True)

# %%
df = df.reset_index(drop=True)

# %%
df #288 products were returned
# Out:
#            Order ID Returned  Postal Code   Region       Product ID  \
# 0    CA-2017-120999     True        60540  Central  TEC-PH-10004093
# 1    US-2017-119662     True        60623  Central  OFF-ST-10003656
# 2    CA-2017-154214     True        47201  Central  FUR-FU-10000206
# 3    CA-2017-140963     True        90045     West  OFF-LA-10003923
# 4    CA-2017-140963     True        90045     West  FUR-BO-10001337
# ..              ...      ...          ...      ...              ...
# 283  CA-2017-169327     True        90008     West  FUR-FU-10004188
# 284  CA-2017-169327     True        90008     West  OFF-BI-10004330
# 285  CA-2017-121258     True        92627     West  FUR-FU-10000747
# 286  CA-2017-121258     True        92627     West  TEC-PH-10003645
# 287  CA-2017-121258     True        92627     West  OFF-PA-10004041
#
#             Category Sub-Category  \
# 0         Technology       Phones
# 1    Office Supplies      Storage
# 2          Furniture  Furnishings
# ...

# %%
df["Profit"].sum() #this amount is the total amount lost by the company because the products above where returned.
# Out:
# 15630.173999999997

# %%
df.plot(title="Most Returned Category", kind = 'line', x= "Category", y= "Quantity",ylabel = "Quantity",figsize=(25,10))
#looks like office supplies are being returned the most
# Out:
# <Axes: title={'center': 'Most Returned Category'}, xlabel='Category', ylabel='Quantity'>

# %%
df.plot(title="Which Region has returned the most", kind = 'area', x= "Region", y= "Quantity",ylabel = "Quantity",figsize=(25,10))
#the western region have returned the most.
# Out:
# <Axes: title={'center': 'Which Region has returned the most'}, xlabel='Region', ylabel='Quantity'>

# %%
df
# Out:
#            Order ID Returned  Postal Code   Region       Product ID  \
# 0    CA-2017-120999     True        60540  Central  TEC-PH-10004093
# 1    US-2017-119662     True        60623  Central  OFF-ST-10003656
# 2    CA-2017-154214     True        47201  Central  FUR-FU-10000206
# 3    CA-2017-140963     True        90045     West  OFF-LA-10003923
# 4    CA-2017-140963     True        90045     West  FUR-BO-10001337
# 5    CA-2017-140963     True        90045     West  TEC-PH-10001924
# 6    CA-2017-137099     True        90008     West  TEC-PH-10002496
# 7    CA-2017-102519     True        53209  Central  FUR-FU-10004091
# 8    CA-2017-102519     True        53209  Central  TEC-AC-10001772
# 9    CA-2017-136539     True        78664  Central  OFF-AR-10001958
# 10   CA-2017-136539     True        78664  Central  FUR-BO-10004709
# 11   US-2017-103247     True        10011     East  TEC-PH-10003555
# 12   US-2017-103247     True        10011     East  OFF-BI-10004492
# ...

# %%
df["Product Name"].nunique() #we have 267 unique products
# Out:
# 267

# %%
pd.set_option("display.max.rows",288)

# %%
df[df["Returned"] == "True"].sort_values(by=["Category","Quantity"], ascending = False)
#Identifying products with the highest return
# Out:
#            Order ID Returned  Postal Code   Region       Product ID  \
# 194  CA-2017-128965     True        90008     West  TEC-AC-10001383
# 204  CA-2017-137414     True        94109     West  TEC-MA-10002930
# 8    CA-2017-102519     True        53209  Central  TEC-AC-10001772
# 17   CA-2017-117212     True        90036     West  TEC-PH-10004447
# 189  CA-2017-123085     True        90008     West  TEC-AC-10000990
# 241  CA-2017-119284     True        37211    South  TEC-PH-10000560
# 11   US-2017-103247     True        10011     East  TEC-PH-10003555
# 28   US-2017-118087     True        19134     East  TEC-PH-10002200
# 45   CA-2017-122504     True        94513     West  TEC-PH-10002468
# 49   CA-2017-124401     True        97206     West  TEC-AC-10002926
#
#        Category Sub-Category  \
# 194  Technology  Accessories
# 204  Technology     Machines
# 8    Technology  Accessories
# 17   Technology       Phones
# 189  Technology  Accessories
# 241  Technology       Phones
# ...

# %%
df2 = df[df["Returned"] == "True"].sort_values(by=["Category","Quantity"], ascending = False).head(10)

# %%
df2 #top 10 most returned products
# Out:
#            Order ID Returned  Postal Code   Region       Product ID  \
# 194  CA-2017-128965     True        90008     West  TEC-AC-10001383
# 204  CA-2017-137414     True        94109     West  TEC-MA-10002930
# 8    CA-2017-102519     True        53209  Central  TEC-AC-10001772
# 17   CA-2017-117212     True        90036     West  TEC-PH-10004447
# 189  CA-2017-123085     True        90008     West  TEC-AC-10000990
# 241  CA-2017-119284     True        37211    South  TEC-PH-10000560
# 11   US-2017-103247     True        10011     East  TEC-PH-10003555
# 28   US-2017-118087     True        19134     East  TEC-PH-10002200
# 45   CA-2017-122504     True        94513     West  TEC-PH-10002468
# 49   CA-2017-124401     True        97206     West  TEC-AC-10002926
#
#        Category Sub-Category  \
# 194  Technology  Accessories
# 204  Technology     Machines
# 8    Technology  Accessories
# 17   Technology       Phones
# 189  Technology  Accessories
# 241  Technology       Phones
# ...

# %%
df2.filter(items=['Region','Category','Product Name',"Quantity"])
# Out:
#       Region    Category                                       Product Name  \
# 194     West  Technology              Logitech Wireless Touch Keyboard K400
# 204     West  Technology  Ricoh - Ink Collector Unit for GX3000 Series P...
# 8    Central  Technology  Memorex Mini Travel Drive 16 GB USB 2.0 Flash ...
# 17      West  Technology                    Toshiba IPT2010-SD IP Telephone
# 189     West  Technology       Imation Bio 2GB USB Flash Drive Imation Corp
# 241    South  Technology  Samsung Galaxy S III - 16GB - pebble blue (T-M...
# 11      East  Technology         Motorola HK250 Universal Bluetooth Headset
# 28      East  Technology                              Samsung Galaxy Note 2
# 45      West  Technology  Plantronics CS 50-USB - headset - Convertible,...
# 49      West  Technology              Logitech Wireless Marathon Mouse M705
#
#      Quantity
# 194        11
# 204        11
# 8           9
# 17          8
# 189         8
# 241         8
# 11          7
# ...

# %%
#The firm can work on these products and discover the reason for their high rate of returns.
